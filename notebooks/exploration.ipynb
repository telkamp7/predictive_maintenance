# %% [markdown]
# # Exploring Predictive Maintenance in Manufacturing
# Welcome to this Jupyter notebook where we delve into the fascinating world of predictive maintnance, a science that has revolutionaed the way manufacturing processes are managed and optimized. In the realm of manufacturing, the implementation of predictive maintenance strategies has become instrumental in minimizing downtime, reducing operational costs, and maximizing the overall efficiency of machinery.
#
# ## Understanding Predictive Maintenance
# Predictive maintenance is a proactive approach to equipment maintenance that relies on data analysis and machine learning techniques to predict when a piece of equipments is likely to fail. By harnessing the power of data generated by sensors, Internet of Things (IoT) devices, and other monitoring tools, manufacturers can move away from traditional, reactive maintenance practives and towards a more strategic and cost-effective approach.
#
# ## Significance in Manufacturing
# In the highly competetive landscape of manufacturing, unplanned equipment downtime can have severe consequences, leading to production delays, increased maintenance costs, and potential quality issues. Predictive maintenance, however, empowers manufacturers to anticipate and address potential issues before they escalate, allowing for scheduled and optimized maintenance activites.
#
# ## Objectives of This Notebook
# In this explorative notebook, we aim to:
#
# - **Understand Key Concepts:** Explore the fundamental concepts of predictive maintenance, including its principles, benefits, and challenges within the manufacturing sector.
# - **Data Exploration:** Analyze real-world open-source data set on bearings to gain insights into patterns and trends associated with bearings performance and failure.
# **Data Set Citation:** J. Lee, H. Qiu, G. Yu, J. Lin, and Rexnord Technical Services (2007). IMS, University of Cincinnati. “Bearing Data Set”, NASA Prognostics Data Repository, NASA Ames Research Center, Moffett Field, CA.
# - **Machine Learning Techniques:** Implement and evaluate deep learning (DP) models for predictive maintenance, understanding how these models can contribute to more informed decision-making.
# - **Visualization and Interpretations:** Utilize visualizations to communicate complex data patterns and interpretations effectively.
#
# Whether you are a data scientist, a manufacturing engineer, or someone interested in the intersection of data science and industrial processes, join us on this exploration into the predictive maintenance landscape in manufacturing. Together, let's uncover valuable insights that can drive efficiency, reduce costs, and pave the way for a more resilient and sustainable futue in manufacturing.
#
# Let the exploration begin! 🚀

# %%
# Importing the neccesary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Merging the data sets
#
# In this sections, we will investigate the organization of the data sets and provide some initial visualizations. Finally, we will proces the datasets and merge them into a single file, than can be used to train our DL models.

# %%
path_to_data_dir = "../data/raw/4.\ Bearings"
